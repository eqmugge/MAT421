# %% [markdown]
# <a href="https://colab.research.google.com/github/eqmugge/MAT421/blob/main/ModuleJ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Laplacian Matrix:
# Graph: n nodes and represented by an n × n adjacency matrix
#
# - The adjacency matrix for directed graphs is not necessarily symmetric, whereas the adjacency matrix for undirected graphs is symmetric.
# Represented by:

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# Matrix vs node graph representing Laplacian Matrix:

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)![1.PNG](data:image/png;base64,...)

# %%
from random import sample
import numpy as np

n = 10
nodes = list(np.arange(n))


V = np.zeros(n, dtype = tuple)
for i in range(n):
    nv = np.random.randint(5)

    itself = True
    while itself:
        cnodes = sample(nodes, nv)
        itself = i in cnodes
    V[i] = cnodes

# Test matrix
A = np.zeros((n,n))
for i in range(n):
    for j in range(n):
        if j in V[i]:
            A[i,j] = np.random.random()*5



# Laplacian of network
J = np.copy(A)
for i in range(n):
    J[i,i] = - np.sum(A[:,i]) - A[i,i]
